# %% [markdown]
# <a href="https://colab.research.google.com/github/savitra-roy/Porfolio/blob/ML-projects/Loan_Approval_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
train =pd.read_csv('train.csv')
test= pd.read_csv('test.csv')
sampl = pd.read_csv('sample_submission.csv')

# %%
train.head(),test.shape
# Out:
# (   person_income person_home_ownership  person_emp_length loan_intent  \
#  0          35000                  RENT                0.0   EDUCATION
#  1          56000                   OWN                6.0     MEDICAL
#  2          28800                   OWN                8.0    PERSONAL
#  3          70000                  RENT               14.0     VENTURE
#  4          60000                  RENT                2.0     MEDICAL
#
#    loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
#  0          B       6000          11.49                 0.17
#  1          C       4000          13.35                 0.07
#  2          A       6000           8.90                 0.21
#  3          B      12000          11.11                 0.17
#  4          A       6000           6.92                 0.10
#
#    cb_person_default_on_file  cb_person_cred_hist_length  loan_status
#  0                         N                          14            0
# ...

# %%
sampl.head()
# Out:
#       id  loan_status
# 0  58645          0.5
# 1  58646          0.5
# 2  58647          0.5
# 3  58648          0.5
# 4  58649          0.5

# %%
train.loan_status.unique()
train.loan_status.value_counts()
# Out:
# loan_status
# 0    50295
# 1     8350
# Name: count, dtype: int64

# %%
train.shape
# Out:
# (58645, 13)

# %%
train.columns
# Out:
# Index(['id', 'person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_default_on_file',
#        'cb_person_cred_hist_length', 'loan_status'],
#       dtype='object')

# %%
train.isna().sum()
# Out:
# id                            0
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# loan_status                   0
# dtype: int64

# %%
train.head()
# Out:
#    id  person_age  person_income person_home_ownership  person_emp_length  \
# 0   0          37          35000                  RENT                0.0
# 1   1          22          56000                   OWN                6.0
# 2   2          29          28800                   OWN                8.0
# 3   3          30          70000                  RENT               14.0
# 4   4          22          60000                  RENT                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0   EDUCATION          B       6000          11.49                 0.17
# 1     MEDICAL          C       4000          13.35                 0.07
# 2    PERSONAL          A       6000           8.90                 0.21
# 3     VENTURE          B      12000          11.11                 0.17
# 4     MEDICAL          A       6000           6.92                 0.10
#
#   cb_person_default_on_file  cb_person_cred_hist_length  loan_status
# ...

# %%
train.drop(['id','person_age'],axis= 1,inplace=True)

# %%
train.head()
# Out:
#    person_income person_home_ownership  person_emp_length loan_intent  \
# 0          35000                  RENT                0.0   EDUCATION
# 1          56000                   OWN                6.0     MEDICAL
# 2          28800                   OWN                8.0    PERSONAL
# 3          70000                  RENT               14.0     VENTURE
# 4          60000                  RENT                2.0     MEDICAL
#
#   loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0          B       6000          11.49                 0.17
# 1          C       4000          13.35                 0.07
# 2          A       6000           8.90                 0.21
# 3          B      12000          11.11                 0.17
# 4          A       6000           6.92                 0.10
#
#   cb_person_default_on_file  cb_person_cred_hist_length  loan_status
# 0                         N                          14            0
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_income               58645 non-null  int64
#  1   person_home_ownership       58645 non-null  object
#  2   person_emp_length           58645 non-null  float64
#  3   loan_intent                 58645 non-null  object
#  4   loan_grade                  58645 non-null  object
#  5   loan_amnt                   58645 non-null  int64
#  6   loan_int_rate               58645 non-null  float64
#  7   loan_percent_income         58645 non-null  float64
#  8   cb_person_default_on_file   58645 non-null  object
#  9   cb_person_cred_hist_length  58645 non-null  int64
#  10  loan_status                 58645 non-null  int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 4.9+ MB

# %%
X= train.drop(['loan_status'],axis=1)
y=train['loan_status']
X
# Out:
#        person_income person_home_ownership  person_emp_length loan_intent  \
# 0              35000                  RENT                0.0   EDUCATION
# 1              56000                   OWN                6.0     MEDICAL
# 2              28800                   OWN                8.0    PERSONAL
# 3              70000                  RENT               14.0     VENTURE
# 4              60000                  RENT                2.0     MEDICAL
# ...              ...                   ...                ...         ...
# 58640         120000              MORTGAGE                5.0   EDUCATION
# 58641          28800                  RENT                0.0     MEDICAL
# 58642          44000                  RENT                7.0   EDUCATION
# 58643          30000                  RENT                2.0   EDUCATION
# 58644          75000              MORTGAGE                2.0     VENTURE
#
#       loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# ...

# %%
cat_features= [features for features in X.columns if X[features].dtypes=='O']
for col in cat_features:
  print(f'{col}: {train[col].value_counts()}\n')
# Out:
# person_home_ownership: person_home_ownership
# RENT        30594
# MORTGAGE    24824
# OWN          3138
# OTHER          89
# Name: count, dtype: int64
#
# loan_intent: loan_intent
# EDUCATION            12271
# MEDICAL              10934
# PERSONAL             10016
# VENTURE              10011
# DEBTCONSOLIDATION     9133
# HOMEIMPROVEMENT       6280
# Name: count, dtype: int64
#
# loan_grade: loan_grade
# A    20984
# B    20400
# C    11036
# D     5034
# E     1009
# F      149
# G       33
# Name: count, dtype: int64
#
# cb_person_default_on_file: cb_person_default_on_file
# N    49943
# Y     8702
# Name: count, dtype: int64

# %%
num_features= [features for features in X.columns if X[features].dtypes!='O']

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
Ohe= OneHotEncoder()
SS= StandardScaler()
CT= ColumnTransformer([('encoder',Ohe,cat_features),('scaler',SS,num_features)],remainder='passthrough')

# %%
X= CT.fit_transform(X)

# %%
X
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.26761564,
#          0.11737777,  2.03179824],
#        [ 0.        ,  0.        ,  1.        , ...,  0.88053209,
#         -0.97324168, -0.94648871],
#        [ 0.        ,  0.        ,  1.        , ..., -0.58585405,
#          0.55362555,  1.03903592],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  1.75377328,
#         -0.10074612, -0.94648871],
#        [ 0.        ,  0.        ,  0.        , ..., -0.58585405,
#          0.11737777, -0.69829813],
#        [ 1.        ,  0.        ,  0.        , ...,  0.14239615,
#          0.4445636 , -0.20191697]])

# %%
import tensorflow as tf
from tensorflow.keras import layers,models

# %%
model =models.Sequential([
    layers.Dense(128,activation='relu'),
    layers.Dense(64,activation='relu'),
    layers.Dense(64,activation='relu'),
    layers.Dense(64,activation='relu'),
    layers.Dense(1,activation='sigmoid')

])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X,y,epochs=30,batch_size=1000,validation_split=0.2,verbose=2)
# Out:
# Epoch 1/30
# 47/47 - 3s - 61ms/step - accuracy: 0.8571 - loss: 0.3779 - val_accuracy: 0.9116 - val_loss: 0.2397
# Epoch 2/30
# 47/47 - 0s - 9ms/step - accuracy: 0.9227 - loss: 0.2234 - val_accuracy: 0.9328 - val_loss: 0.1975
# Epoch 3/30
# 47/47 - 0s - 9ms/step - accuracy: 0.9360 - loss: 0.1982 - val_accuracy: 0.9390 - val_loss: 0.1852
# Epoch 4/30
# 47/47 - 0s - 9ms/step - accuracy: 0.9405 - loss: 0.1894 - val_accuracy: 0.9433 - val_loss: 0.1786
# Epoch 5/30
# 47/47 - 1s - 13ms/step - accuracy: 0.9427 - loss: 0.1845 - val_accuracy: 0.9454 - val_loss: 0.1754
# Epoch 6/30
# 47/47 - 1s - 20ms/step - accuracy: 0.9447 - loss: 0.1810 - val_accuracy: 0.9453 - val_loss: 0.1748
# Epoch 7/30
# 47/47 - 1s - 27ms/step - accuracy: 0.9454 - loss: 0.1794 - val_accuracy: 0.9479 - val_loss: 0.1743
# Epoch 8/30
# 47/47 - 0s - 10ms/step - accuracy: 0.9449 - loss: 0.1784 - val_accuracy: 0.9479 - val_loss: 0.1731
# Epoch 9/30
# ...

# %%
test.head()
# Out:
#       id  person_age  person_income person_home_ownership  person_emp_length  \
# 0  58645          23          69000                  RENT                3.0
# 1  58646          26          96000              MORTGAGE                6.0
# 2  58647          26          30000                  RENT                5.0
# 3  58648          33          50000                  RENT                4.0
# 4  58649          26         102000              MORTGAGE                8.0
#
#          loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0    HOMEIMPROVEMENT          F      25000          15.76
# 1           PERSONAL          C      10000          12.68
# 2            VENTURE          E       4000          17.19
# 3  DEBTCONSOLIDATION          A       7000           8.90
# 4    HOMEIMPROVEMENT          D      15000          16.32
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# ...

# %%
test.drop(['id','person_age'],axis=1,inplace=True)

# %%
test.shape
# Out:
# (39098, 10)

# %%
cat_features1= [features for features in test.columns if test[features].dtypes=='O']
for col in cat_features:
  print(f'{col}: {train[col].value_counts()}\n')
num_features1= [features for features in test.columns if test[features].dtypes!='O']
len(cat_features1),len(num_features1)
# Out:
# person_home_ownership: person_home_ownership
# RENT        30594
# MORTGAGE    24824
# OWN          3138
# OTHER          89
# Name: count, dtype: int64
#
# loan_intent: loan_intent
# EDUCATION            12271
# MEDICAL              10934
# PERSONAL             10016
# VENTURE              10011
# DEBTCONSOLIDATION     9133
# HOMEIMPROVEMENT       6280
# Name: count, dtype: int64
#
# loan_grade: loan_grade
# A    20984
# B    20400
# C    11036
# D     5034
# E     1009
# F      149
# G       33
# Name: count, dtype: int64
#
# cb_person_default_on_file: cb_person_default_on_file
# N    49943
# Y     8702
# Name: count, dtype: int64
# (4, 6)

# %%
columnTransformer1= ColumnTransformer([('encoder',Ohe,cat_features1),('scaler',SS,num_features1)],remainder='passthrough')

# %%
columnTransformer1
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('encoder', OneHotEncoder(),
#                                  ['person_home_ownership', 'loan_intent',
#                                   'loan_grade', 'cb_person_default_on_file']),
#                                 ('scaler', StandardScaler(),
#                                  ['person_income', 'person_emp_length',
#                                   'loan_amnt', 'loan_int_rate',
#                                   'loan_percent_income',
#                                   'cb_person_cred_hist_length'])])

# %%
X_test= columnTransformer1.fit_transform(test)

# %%
X_test
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  1.68823792,
#          2.18729516, -0.94071931],
#        [ 1.        ,  0.        ,  0.        , ...,  0.66843149,
#         -0.65013457, -0.44957279],
#        [ 0.        ,  0.        ,  0.        , ...,  2.16171948,
#         -0.32273883, -0.94071931],
#        ...,
#        [ 1.        ,  0.        ,  0.        , ..., -1.04338645,
#          0.98684412,  4.7074656 ],
#        [ 1.        ,  0.        ,  0.        , ...,  1.64188308,
#          2.5146909 , -0.44957279],
#        [ 0.        ,  0.        ,  0.        , ..., -0.24873209,
#          3.06035046,  0.77829349]])

# %%
y_pred= model.predict(X_test)
# Out:
# 1222/1222 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
sampl.head()
# Out:
#       id  loan_status
# 0  58645          0.5
# 1  58646          0.5
# 2  58647          0.5
# 3  58648          0.5
# 4  58649          0.5

# %%
sampl.loan_status.value_counts()
# Out:
# loan_status
# 0.010030    2
# 0.015523    2
# 0.052552    2
# 0.015477    2
# 0.035106    2
#            ..
# 0.031229    1
# 0.010370    1
# 0.010630    1
# 0.031994    1
# 0.990009    1
# Name: count, Length: 39027, dtype: int64

# %%
sampl['loan_status']= y_pred

# %%
sampl.to_csv('ans.csv',index= False)

# %%
df= pd.read_csv('ans.csv')

# %%
df
# Out:
#           id  loan_status
# 0      58645     0.992455
# 1      58646     0.038614
# 2      58647     0.726494
# 3      58648     0.025868
# 4      58649     0.117491
# ...      ...          ...
# 39093  97738     0.023003
# 39094  97739     0.005098
# 39095  97740     0.017085
# 39096  97741     0.241927
# 39097  97742     0.990009
#
# [39098 rows x 2 columns]

# %%
predictions = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 1222/1222 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
predictions
# Out:
# array([[1],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [1]], dtype=int32)

# %%
# Out:
# 0.14231019
